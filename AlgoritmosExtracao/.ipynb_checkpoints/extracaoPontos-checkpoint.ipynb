# %%
import requests
import pandas as pd
import sqlite3
import logging

# Configuração de logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Função para criar a tabela no banco de dados SQLite (se ainda não existir)
def criar_tabela():
    with sqlite3.connect('dados_pontos.db') as conn:
        conn.execute('''
            CREATE TABLE IF NOT EXISTS onibus (
                NOME TEXT,
                NUM TEXT,
                Latitude REAL,
                Longitude REAL,
                SEQ INTEGER,
                GRUPO TEXT,
                SENTIDO TEXT,
                TIPO TEXT,
                ID_do_Itinerario INTEGER,
                COD TEXT
            )
        ''')
        conn.commit()

# Função para buscar e processar dados da linha de ônibus
def buscar_e_processar_dados(linha):
    url = f'https://transporteservico.urbs.curitiba.pr.gov.br/getPontosLinha.php?linha={linha:03}&c=821f0'
    
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        dados_json = response.json()

        if not dados_json:
            return None

        # Criar DataFrame a partir dos dados
        df = pd.DataFrame.from_records(dados_json)

        # Substituir vírgulas por pontos e converter tipos
        df['Latitude'] = df['LAT'].str.replace(',', '.').astype(float)
        df['Longitude'] = df['LON'].str.replace(',', '.').astype(float)
        df['SEQ'] = df['SEQ'].astype(int)
        df['ID_do_Itinerario'] = df['ITINERARY_ID'].astype(int)
        
        # Adicionar coluna COD
        df['COD'] = linha

        return df[['NOME', 'NUM', 'Latitude', 'Longitude', 'SEQ', 'GRUPO', 'SENTIDO', 'TIPO', 'ID_do_Itinerario', 'COD']]

    except requests.RequestException as e:
        logging.error(f"Erro na requisição para a linha {linha}: {e}")
    except Exception as e:
        logging.error(f"Erro ao processar a linha {linha}: {e}")
    return None

# Função para carregar a tabela de ônibus em um DataFrame
def carregar_tabela_para_dataframe(nome_tabela, db='dados_pontos.db'):
    try:
        with sqlite3.connect(db) as conn:
            cursor = conn.cursor()

            cursor.execute("""
                SELECT name FROM sqlite_master WHERE type='table' AND name=?;
            """, (nome_tabela,))
            resultado = cursor.fetchone()

            if resultado:
                df = pd.read_sql(f'SELECT * FROM {nome_tabela}', conn)
            else:
                df = pd.DataFrame()

        return df
    except Exception as e:
        logging.error(f"Erro ao carregar a tabela {nome_tabela}: {e}")
        return pd.DataFrame()

# Função para gravar os dados no banco de dados SQLite
def gravar_no_banco(df_result):
    try:
        with sqlite3.connect('dados_pontos.db') as conn:
            df_result.to_sql('onibus', conn, if_exists='append', index=False)
    except Exception as e:
        logging.error(f"Erro ao gravar no banco de dados: {e}")

# Função para processar as linhas de ônibus de forma sequencial
def processar_linhas_sequencialmente(linhas_unicas, df_onibus):
    result_list = []

    for linha in linhas_unicas:
        df_result = buscar_e_processar_dados(linha)
        if df_result is not None:
            result_list.append(df_result)

    if result_list:
        df_concatenado = pd.concat(result_list, ignore_index=True)
        
        df_onibus['COD'] = df_onibus['COD'].astype(int)
        df_novos_pontos = df_concatenado[~df_concatenado['COD'].isin(df_onibus['COD'])]

        if not df_novos_pontos.empty:
            if not df_onibus.empty:
                gravar_no_banco(df_novos_pontos)
                logging.info(f"Novas linhas encontradas, total de linhas inseridas: {len(df_novos_pontos)}")
                logging.info(f"Novas linhas: {df_novos_pontos['COD'].unique()}")
            else:
                gravar_no_banco(df_concatenado)
                logging.info(f"Base de dados vazia, total de linhas inseridas: {len(df_concatenado)}")
                logging.info(f"Novas linhas: {df_novos_pontos['COD'].unique()}")
        else:
            logging.info("Nenhum novo ponto para gravar.")

# Função para remover duplicatas
def remover_duplicatas():
    logging.info("Removendo duplicatas da tabela onibus...")
    
    with sqlite3.connect('dados_pontos.db') as conn:
        cursor = conn.cursor()
        
        cursor.execute('''
            DELETE FROM onibus
            WHERE rowid NOT IN (
                SELECT MIN(rowid)
                FROM onibus
                GROUP BY COD, Latitude, Longitude
            )
        ''')
        conn.commit()

# Inicializar o processamento sequencial
def iniciar_processamento():
    linhas_unicas = range(0, 1000)  # Exemplo de intervalo de linhas
    criar_tabela()  # Garantir que a tabela está criada

    try:
        #df_onibus = carregar_tabela_para_dataframe('onibus')
        #processar_linhas_sequencialmente(linhas_unicas, df_onibus)
        remover_duplicatas()  # Chamar a função de remoção de duplicatas
    except Exception as e:
        logging.error(f"Erro durante o processamento: {e}")
    finally:
        logging.info("Processamento finalizado.")

iniciar_processamento()
# Out:
# 2024-10-22 22:42:22,897 - INFO - Removendo duplicatas da tabela onibus...
# 2024-10-22 22:42:22,941 - INFO - Processamento finalizado.

# %%
df = carregar_tabela_para_dataframe('onibus')
df[df['COD'] == '170']
# Out:
#                                                    NOME     NUM   Latitude  \
# 1175         Rua Domingos Antônio Moro, 93 - Pilarzinho  120328 -25.385060
# 1176              R. Des. Hugo Simas, 1299 - Bom Retiro  120337 -25.407465
# 1177               R. Des. Hugo Simas, 961 - Bom Retiro  120339 -25.409967
# 1178                 Av. Fredolin Wolf, 64 - Pilarzinho  120717 -25.383264
# 1179     Rua Des. Benvindo Valente, 104 - São Francisco  110011 -25.420492
# 1180                  R. Albino Silva, 122 - Bom Retiro  110009 -25.416686
# 1181                 Av. Fredolin Wolf, 64 - Pilarzinho  120322 -25.383204
# 1182              R. Des. Hugo Simas, 1110 - Bom Retiro  120338 -25.409718
# 1183        R. Amauri Lange Silvério, 1167 - Pilarzinho  120068 -25.387754
# 1184       Rua José Ribeiro de Cristo, 311 - Pilarzinho  120319 -25.380972
# 1185              R. Des. Hugo Simas, 2672 - Pilarzinho  120024 -25.397184
# 1186              R. Des. Hugo Simas, 1450 - Bom Retiro  120336 -25.406914
# 1187              R. Des. Hugo Simas, 1637 - Pilarzinho  120335 -25.404610
# 1188           Rua Duque de Caxias, 155 - São Francisco  110018 -25.425881
# 1189            Rua José Izidoro Filho, 22 - Pilarzinho  120605 -25.381024
# 1190        R. Amauri Lange Silvério, 1418 - Pilarzinho  120609 -25.386260
# 1191              Rua Trajano Reis, 296 - São Francisco  110133 -25.424296
# 1192                   R. Nilo Peçanha,162 - Bom Retiro  110008 -25.418907
# 1193             Rua Treze de Maio, 503 - São Francisco  110187 -25.426929
# 1194         R. Amauri Lange Silvério, 231 - Pilarzinho  120033 -25.394949
# 1195  R. José Ribeiro de Cristo, 168 - Pilarzinho, C...  121033 -25.381978
# 1196         Rua Otalino Amado de Souza, 1 - Pilarzinho  120317 -25.381671
# 1197              R. Des. Hugo Simas, 2300 - Bom Retiro  120332 -25.400776
# 1198              R. Des. Hugo Simas, 1856 - Bom Retiro  120334 -25.402874
# 1199  R. José Ribeiro de Cristo, 190 - Pilarzinho, C...  121034 -25.381759
# 1200              R. Des. Hugo Simas, 2300 - Bom Retiro  120333 -25.400987
# 1201                               R. Nilo Peçanha, 760  110462 -25.420660
# 1202         R. Amauri Lange Silvério, 828 - Pilarzinho  120043 -25.390875
# 1203       Rua José Ribeiro de Cristo, 311 - Pilarzinho  120606 -25.380907
# 1204                  Av. Fredolin Wolf, 448 - São João  120608 -25.383329
# 1205               R. Des. Hugo Simas, 259 - Bom Retiro  110129 -25.416240
# 1206     Rua José Ribeiro de Cristo, 1-119 - Pilarzinho  120607 -25.382745
# 1207         R. Amauri Lange Silvério, 232 - Pilarzinho  120032 -25.395021
# 1208                         R. Teffé, 284 - Bom Retiro  110132 -25.414802
# 1209      Rua Lilian Júlia de Oliveira, 23 - Pilarzinho  120716 -25.382330
# 1210       R. Amauri Lange Silvério, 00511 - Pilarzinho  120041 -25.393425
# 1211                Nestor de Castro - 170 - Bracatinga  101126 -25.428255
# 1212        Rua Domingos Antônio Moro, 296 - Pilarzinho  120326 -25.384330
# 1213              R. Des. Hugo Simas, 2495 - Pilarzinho  120331 -25.399380
# 1214               R. Des. Hugo Simas, 581 - Bom Retiro  120340 -25.413951
# 1215      R. José Ribeiro de Cristo, 2-120 - Pilarzinho  120612 -25.383010
# 1216     R. P-min. Brochado da Rocha, 1186 - Pilarzinho  120042 -25.393233
# 1217        R. Amauri Lange Silvério, 1168 - Pilarzinho  120069 -25.388122
# 1218        Rua Domingos Antônio Moro, 314 - Pilarzinho  120327 -25.383666
# 1219         Rua Domingos Antônio Moro, 93 - Pilarzinho  120329 -25.385005
# 1220              R. Des. Hugo Simas, 2496 - Pilarzinho  120330 -25.399257
# 1221               R. Des. Hugo Simas, 566 - Bom Retiro  120341 -25.413777
# 1222        Rua Amauri Lange Silvério, 900 - Pilarzinho  120067 -25.390591
# 1223              R. Des. Hugo Simas, 2796 - Pilarzinho  120030 -25.396850
# 1224        Rua Otalino Amado de Souza, 23 - Pilarzinho  120318 -25.380310
# 1225                  Av. Fredolin Wolf, 592 - São João  120320 -25.383240
# 1226                  Av. Fredolin Wolf, 438 - São João  120321 -25.383568
# 1227            Rua Inácio Lustosa, 434 - São Francisco  110201 -25.423649
# 1228      R. Des. Benvindo Valente, 285 - São Francisco  110010 -25.419298
#
#       Longitude  SEQ GRUPO           SENTIDO             TIPO  \
# 1175 -49.284824   10        Nestor de Castro    Chapéu chinês
# 1176 -49.283062   19        Nestor de Castro  Novo mobiliário
# 1177 -49.281960   20        Nestor de Castro  Novo mobiliário
# 1178 -49.288224    8        Nestor de Castro    Chapéu chinês
# 1179 -49.275230    4              Bracatinga  Novo mobiliário
# 1180 -49.276544    6              Bracatinga  Novo mobiliário
# 1181 -49.288327   22              Bracatinga    Chapéu chinês
# 1182 -49.281924    9              Bracatinga  Novo mobiliário
# 1183 -49.282962   11        Nestor de Castro  Novo mobiliário
# 1184 -49.296646    3        Nestor de Castro    Chapéu chinês
# 1185 -49.287881   14              Bracatinga  Novo mobiliário
# 1186 -49.282782   10              Bracatinga  Novo mobiliário
# 1187 -49.282541   18        Nestor de Castro  Novo mobiliário
# 1188 -49.273238    2              Bracatinga  Novo mobiliário
# 1189 -49.299663   27              Bracatinga    Placa em cano
# 1190 -49.282410   19              Bracatinga    Placa em cano
# 1191 -49.274191   25        Nestor de Castro  Novo mobiliário
# 1192 -49.274697   23        Nestor de Castro  Novo mobiliário
# 1193 -49.271383   26        Nestor de Castro    Placa em cano
# 1194 -49.285349   14        Nestor de Castro  Novo mobiliário
# 1195 -49.294878    4        Nestor de Castro    Chapéu chinês
# 1196 -49.300806   29              Bracatinga    Chapéu chinês
# 1197 -49.285298   12              Bracatinga  Novo mobiliário
# 1198 -49.282577   11              Bracatinga  Novo mobiliário
# 1199 -49.294944   25              Bracatinga    Placa em cano
# 1200 -49.285160   17        Nestor de Castro  Novo mobiliário
# 1201 -49.274778   24        Nestor de Castro  Novo mobiliário
# 1202 -49.283135   17              Bracatinga  Novo mobiliário
# 1203 -49.296690   26              Bracatinga    Placa em cano
# 1204 -49.291901   23              Bracatinga    Chapéu chinês
# 1205 -49.279140   22        Nestor de Castro  Novo mobiliário
# 1206 -49.293669   24              Bracatinga   Sem demarcação
# 1207 -49.285215   15              Bracatinga  Novo mobiliário
# 1208 -49.277617    7              Bracatinga  Novo mobiliário
# 1209 -49.300469   28              Bracatinga   Placa em poste
# 1210 -49.283994   13        Nestor de Castro  Novo mobiliário
# 1211 -49.272499   27        Nestor de Castro  Novo mobiliário
# 1212 -49.285894    9        Nestor de Castro    Chapéu chinês
# 1213 -49.287375   16        Nestor de Castro  Novo mobiliário
# 1214 -49.279377   21        Nestor de Castro  Novo mobiliário
# 1215 -49.293590    5        Nestor de Castro    Chapéu chinês
# 1216 -49.283519   16              Bracatinga  Novo mobiliário
# 1217 -49.282947   18              Bracatinga  Novo mobiliário
# 1218 -49.286453   21              Bracatinga    Chapéu chinês
# 1219 -49.284676   20              Bracatinga    Chapéu chinês
# 1220 -49.287324   13              Bracatinga  Novo mobiliário
# 1221 -49.279280    8              Bracatinga  Novo mobiliário
# 1222 -49.283552   12        Nestor de Castro  Novo mobiliário
# 1223 -49.287910   15        Nestor de Castro  Novo mobiliário
# 1224 -49.299810    2        Nestor de Castro    Chapéu chinês
# 1225 -49.293051    6        Nestor de Castro    Chapéu chinês
# 1226 -49.291066    7        Nestor de Castro            Domus
# 1227 -49.273810    3              Bracatinga    Placa em cano
# 1228 -49.276073    5              Bracatinga  Novo mobiliário
#
#       ID_do_Itinerario  COD
# 1175              8653  170
# 1176              8653  170
# 1177              8653  170
# 1178              8653  170
# 1179              8673  170
# 1180              8673  170
# 1181              8673  170
# 1182              8673  170
# 1183              8653  170
# 1184              8653  170
# 1185              8673  170
# 1186              8673  170
# 1187              8653  170
# 1188              8673  170
# 1189              8673  170
# 1190              8673  170
# 1191              8653  170
# 1192              8653  170
# 1193              8653  170
# 1194              8653  170
# 1195              8653  170
# 1196              8673  170
# 1197              8673  170
# 1198              8673  170
# 1199              8673  170
# 1200              8653  170
# 1201              8653  170
# 1202              8673  170
# 1203              8673  170
# 1204              8673  170
# 1205              8653  170
# 1206              8673  170
# 1207              8673  170
# 1208              8673  170
# 1209              8673  170
# 1210              8653  170
# 1211              8653  170
# 1212              8653  170
# 1213              8653  170
# 1214              8653  170
# 1215              8653  170
# 1216              8673  170
# 1217              8673  170
# 1218              8673  170
# 1219              8673  170
# 1220              8673  170
# 1221              8673  170
# 1222              8653  170
# 1223              8653  170
# 1224              8653  170
# 1225              8653  170
# 1226              8653  170
# 1227              8673  170
# 1228              8673  170

# %%
df
# Out:
#                                                     NOME     NUM   Latitude  \
# 0                         Av. Manoel Ribas, 531 - Mercês  110037 -25.422483
# 1                     Rua Augusto Stresser, 517 - Juvevê  130238 -25.417083
# 2                              Rua Chile, 821 - Rebouças  140051 -25.447454
# 3          R. Dep. Mário de Barros, 1681 - Centro Cívico  120112 -25.411726
# 4            R. Alm. Tamandaré, 272 - Alto da Rua Quinze  130268 -25.430345
# ...                                                  ...     ...        ...
# 14297                   Rua João Golin, 2 - Butiatuvinha  190753 -25.393788
# 14298           Av. Napoleão Manosso, 553 - Butiatuvinha  190155 -25.393658
# 14299            Rua Via Veneto, 1593 - Santa Felicidade  190239 -25.399836
# 14300  Rua Professor Francisco Zardo, 479 - Santa Fel...  190167 -25.404782
# 14301                  Rua Acelino Grande, 542- São Braz  190386 -25.404399
#
#        Longitude  SEQ GRUPO                    SENTIDO             TIPO  \
# 0     -49.284328   37                          Horário  Novo mobiliário
# 1     -49.256173    6                          Horário  Novo mobiliário
# 2     -49.257707   18                          Horário  Novo mobiliário
# 3     -49.270902   42                          Horário  Novo mobiliário
# 4     -49.255576   10                          Horário  Novo mobiliário
# ...          ...  ...   ...                        ...              ...
# 14297 -49.344422   10                       Ouro Verde   Placa em poste
# 14298 -49.341903    6        Terminal Santa Felicidade    Chapéu chinês
# 14299 -49.333621   25        Terminal Santa Felicidade  Novo mobiliário
# 14300 -49.340524   21        Terminal Santa Felicidade    Chapéu chinês
# 14301 -49.344898   19        Terminal Santa Felicidade            Domus
#
#        ID_do_Itinerario  COD
# 0                   481   10
# 1                   481   10
# 2                   481   10
# 3                   481   10
# 4                   481   10
# ...                 ...  ...
# 14297              8120  948
# 14298              8136  948
# 14299             12854  948
# 14300             12854  948
# 14301             12854  948
#
# [14302 rows x 10 columns]
