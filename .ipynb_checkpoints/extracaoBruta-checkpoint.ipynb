# %%
import geopy
import requests
import pandas as pd
from datetime import datetime
from geopy.distance import geodesic
import logging
import pytz
import threading
import time

# Função para buscar e processar os dados de uma linha de ônibus
def buscar_e_processar_dados(linha):
    url_base = f'https://transporteservico.urbs.curitiba.pr.gov.br/getVeiculos.php?linha={linha:03}&c=821f0'
    
    try:
        # Definir o timeout para 10 segundos
        response = requests.get(url_base, timeout=30)
        response.raise_for_status()

        timezone_sp = pytz.timezone('America/Sao_Paulo')
        hora_online = datetime.now(timezone_sp).strftime("%Y-%m-%d %H:%M:%S")
        dados_json = response.json()

        # Verificar se a resposta é uma lista (caso não haja dados)
        if isinstance(dados_json, list):
            return None

        # Processar os dados e criar o DataFrame
        codigos_onibus = [{
            "COD": valor['COD'],
            "REFRESH": valor['REFRESH'],
            "LAT_IN_TIME": valor['LAT'],
            "LON_IN_TIME": valor['LON'],
            "CODIGOLINHA": int(valor['CODIGOLINHA']),
            "ADAPT": int(valor['ADAPT']),
            "TIPO_VEIC": int(valor['TIPO_VEIC']),
            "TABELA": valor['TABELA'],
            "SITUACAO": valor['SITUACAO'],
            "SITUACAO2": valor['SITUACAO2'],
            "SENT": valor['SENT'],
            "TCOUNT": valor['TCOUNT'],
            "SENTIDO_IN_TIME": valor['SENTIDO']
        } for chave, valor in dados_json.items()]

        df_codigos_onibus = pd.DataFrame(codigos_onibus)

        # Adicionar a hora online se houver dados
        if not df_codigos_onibus.empty:
            df_codigos_onibus['HORA'] = hora_online
        else:
            logging.warning("Nenhum ônibus encontrado em operação para a linha %s", linha)
            return None

        return df_codigos_onibus

    except requests.Timeout:
        logging.error("Timeout: A conexão para a linha %s demorou mais de 10 segundos", linha)
        return None
    except requests.RequestException as e:
        logging.error("Falha ao acessar a página para a linha %s: %s", linha, e)
        return None
    except Exception as e:
        logging.error("Erro ao processar dados para a linha %s: %s", linha, e)
        return None


# Função que será executada por cada thread para processar as linhas
def processar_linha(linha, df_linhas, result_list):
    df_result = buscar_e_processar_dados(linha)
    if df_result is not None:
        # Filtrar o DataFrame de linhas para a linha específica
        df_linha_atual = df_linhas[df_linhas['COD'] == linha]
        result_list.append(df_result)

######################################################################################################################

# Carregar os dados dos pontos da linha
df_linhas = pd.read_csv('df_pontos.csv')

# Obter os códigos únicos das linhas
linhas_unicas = df_linhas['COD'].unique()

# DataFrame final que irá armazenar todos os resultados concatenados
df_concatenado = pd.DataFrame()

# Função para gerenciar threads e processamento de dados
def processar_linhas_com_threads(linhas_unicas, df_linhas):
    i = 0
    while True:
        result_list = []
        
        # Criar threads para cada linha
        threads = [threading.Thread(target=processar_linha, args=(linha, df_linhas, result_list)) for linha in linhas_unicas]

        # Iniciar todas as threads
        for thread in threads:
            thread.start()

        # Esperar todas as threads terminarem
        for thread in threads:
            thread.join()

        # Concatenar os resultados de todas as threads em um DataFrame
        if result_list:
            global df_concatenado
            df_concatenado = pd.concat([df_concatenado] + result_list, ignore_index=True)

        # Log da iteração atual
        logging.info('Número atual da iteração: %s', i)
        i += 1
        break
        # Espera 60 segundos antes da próxima iteração
        time.sleep(60)

# Inicializando o processo com threads
processar_linhas_com_threads(linhas_unicas, df_linhas)
# Out:
# ERROR:root:Timeout: A conexão para a linha 546 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 548 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 547 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 536 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 614 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 549 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 552 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 603 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 607 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 550 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 600 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 561 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 553 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 560 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 602 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 611 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 610 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 609 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 615 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 612 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 621 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 623 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 622 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 617 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 619 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 620 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 616 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 625 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 627 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 624 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 631 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 630 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 629 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 635 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 628 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 636 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 632 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 638 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 633 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 637 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 640 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 639 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 653 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 652 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 654 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 658 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 649 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 657 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 659 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 655 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 661 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 662 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 665 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 663 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 670 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 668 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 666 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 674 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 671 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 679 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 673 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 681 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 684 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 680 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 689 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 690 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 702 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 685 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 701 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 703 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 700 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 683 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 711 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 712 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 710 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 706 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 720 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 707 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 713 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 760 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 718 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 721 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 732 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 722 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 723 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 724 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 762 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 777 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 778 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 761 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 788 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 772 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 779 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 789 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 809 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 773 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 816 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 814 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 815 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 821 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 822 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 827 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 823 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 820 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 825 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 860 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 826 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 861 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 817 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 828 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 831 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 829 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 863 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 862 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 832 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 870 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 875 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 864 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 911 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 889 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 876 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 865 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 912 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 902 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 901 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 916 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 917 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 928 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 958 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 965 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 967 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 972 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 948 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 979 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 989 demorou mais de 10 segundos
# ERROR:root:Timeout: A conexão para a linha 183 demorou mais de 10 segundos

# %%
df_concatenado
# Out:
#        COD REFRESH LAT_IN_TIME LON_IN_TIME  CODIGOLINHA  ADAPT  TIPO_VEIC  \
# 0    EB609   21:35  -25.426071  -49.299401           21      1          4
# 1    GB601   21:35  -25.387705  -49.267651           21      1          4
# 2    GB602   21:34  -25.411448  -49.247345           21      1          4
# 3    EB603   21:35  -25.481028  -49.298403           21      1          4
# 4    BB608   21:35  -25.445036  -49.221438           21      1          4
# ..     ...     ...         ...         ...          ...    ...        ...
# 285  GB606   21:35  -25.530065  -49.298846          545      1          4
# 286  MI003   21:35  -25.389485  -49.298291          924      1          1
# 287  BI019   21:30  -25.377548   -49.22415          924      1          1
# 288  MI004   21:35  -25.392143   -49.31873          924      1          1
# 289  MC306   21:34  -25.428126  -49.271521          924      1          3
#
#     TABELA    SITUACAO        SITUACAO2      SENT  TCOUNT  \
# 0        2  NO HORÁRIO  REALIZANDO ROTA  CIRCULAR       1
# 1      8-2  NO HORÁRIO  REALIZANDO ROTA  CIRCULAR       1
# 2      6-2  NO HORÁRIO  REALIZANDO ROTA  CIRCULAR       1
# 3        3  NO HORÁRIO  REALIZANDO ROTA  CIRCULAR       1
# 4        1  NO HORÁRIO  REALIZANDO ROTA  CIRCULAR       1
# ..     ...         ...              ...       ...     ...
# 285      1  NO HORÁRIO  REALIZANDO ROTA       IDA       1
# 286      7  NO HORÁRIO  REALIZANDO ROTA       IDA       1
# 287    6-2   ADIANTADO  REALIZANDO ROTA     VOLTA       1
# 288      1   ADIANTADO  REALIZANDO ROTA     VOLTA       1
# 289      3  NO HORÁRIO  REALIZANDO ROTA       IDA       1
#
#                                  SENTIDO_IN_TIME                 HORA
# 0       827-TERMINAL CAMPINA DO SIQUEIRA (21:39)  2024-10-15 21:36:39
# 1       827-TERMINAL CAMPINA DO SIQUEIRA (22:00)  2024-10-15 21:36:39
# 2                    819-TERMINAL CABRAL (21:46)  2024-10-15 21:36:39
# 3                833-TERMINAL CAPAO RASO (21:42)  2024-10-15 21:36:39
# 4           832-TERMINAL CAPAO DA IMBUIA (21:43)  2024-10-15 21:36:39
# ..                                           ...                  ...
# 285      1081-T.S.CERCADO SENT.BOQUEIRAO (21:50)  2024-10-15 21:36:42
# 286  1569-CRUZ DO PILARZINHO/STA.CANDIDA (21:40)  2024-10-15 21:36:42
# 287  1570-CRUZ DO PILARZINHO/STA.FELICID (21:58)  2024-10-15 21:36:42
# 288        881-TERMINAL SANTA FELICIDADE (21:50)  2024-10-15 21:36:42
# 289                                               2024-10-15 21:36:42
#
# [290 rows x 14 columns]

# %%
from geopy.geocoders import Nominatim

def obter_bairro(lat, lon):
    geolocator = Nominatim(user_agent="meu_app")
    location = geolocator.reverse((lat, lon), exactly_one=True)
    
    if location and 'suburb' in location.raw['address']:
        return location.raw['address']['suburb']
    else:
        return "Bairro não encontrado"

# Exemplo de coordenadas
lat =  -25.4297
lon = -49.2719

bairro = obter_bairro(lat, lon)
print(f"O ônibus está no bairro: {bairro}")
# Out:
# O ônibus está no bairro: Centro
